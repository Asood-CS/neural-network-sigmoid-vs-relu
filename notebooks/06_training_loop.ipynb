# %% [markdown]
# #06 - Training Loop

# %% [markdown]
# Once the model environment and data collection functions were set up, I implemented a loop to train my network on the normalized wine quality features. This involved cycling through training data for multiple epochs, performing gradient descent at every step. In all iterations of the loop, I made sure to measure my desired metrics for both accuracy and loss curvature, and to log these values into my data frame. This way, I was able to evaluate the progressive improvement of my model with time, seeing how both activation functions contributed to training speed.

# %%
#Importing all existing network configurations
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd().parent / "src"))
from utils import make_mlp, set_seed, plot_loss

# %%
def train_and_log(activation_name, activation_fn):
    #Re-establishing key hyperparameters
    factor = 0.95
    model = SimpleNeuralNetwork(activation=activation_fn)
    optimizer = optim.Adam(model.parameters(), lr=5e-4)
    criterion = nn.BCELoss()

    logs = []
    train_loss = None

    #Training over multiple epochs
    for epoch in range(num_epochs):
        model.train()
        for step, (batch_x, batch_y) in enumerate(dataloader):
            #Calculating Lipschitz metrics at the start of each training step
            optimizer.zero_grad()

            lower = lipschitz_lower_bound(model, batch_x)
            upper = lipschitz_upper_bound(model, 0.25)

            #Calculating loss and performing backpropagation
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()

            optimizer.step()

            #Calculating largest Hessian eigenvalue
            lam_max = max_hessian_eigval(model, criterion, batch_x.detach(), batch_y.detach())

            if train_loss is None:
                train_loss = loss.detach().item()
            else:
                train_loss = factor * train_loss + (1 - factor) * loss.detach().item()

            #Logging metrics per step on data frame
            logs.append({
                'epoch': epoch,
                'step': step,
                'activation': activation_name,
                'train_loss': np.nan,
                'val_loss': np.nan,
                'f1_score': np.nan,
                'lipschitz_upper': upper,
                'lipschitz_lower': lower,
                'max_hessian_eigval': lam_max
            })

        #Running model in evaluation mode against validation data
        model.eval()
        with torch.no_grad():
            val_labels = []
            val_predictions = []
            val_outputs = []
            val_losses = []

            #Calculating loss metrics for the validation set
            for val_x, val_y in val_dataloader:
                outputs = model(val_x)
                loss = criterion(outputs, val_y)
                predictions = (outputs >= 0.5).int()
                val_labels.append(val_y)
                val_predictions.append(predictions)
                val_outputs.append(outputs)
                val_losses.append(loss)

            val_labels = torch.cat(val_labels, dim=0)
            val_predictions = torch.cat(val_predictions, dim=0)
            val_outputs = torch.cat(val_outputs, dim=0)
            val_loss = torch.stack(val_losses).mean().item()

            best_f1, best_threshold = find_best_f1(val_outputs, val_labels)

        #Condensing step-level logs into an epoch-level log
        logs.append({
            'epoch': epoch,
            'step': np.nan,
            'activation': activation_name,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'f1_score': best_f1,
            'lipschitz_upper': np.nan,
            'lipschitz_lower': np.nan,
            'max_hessian_eigval': np.nan
        })

        print(f'Activation: {activation_name}, Epoch {epoch}: train_loss={train_loss:.4f}, val_loss={val_loss:.4f}, val_f1={best_f1:.3f}, threshold={best_threshold}')

    return logs

#Training and logging for both activation functions
all_logs = []

for act_name, act_fn in [('relu', F.relu), ('sigmoid', torch.sigmoid)]:
    logs = train_and_log(act_name, act_fn)
    all_logs.extend(logs)

#Creating a combined data frame after all runs
df_all = pd.DataFrame(all_logs)

print(df_all.head())
# Out:
# Activation: relu, Epoch 0: train_loss=0.5689, val_loss=0.5453, val_f1=0.346, threshold=0.3
# Activation: relu, Epoch 1: train_loss=0.4739, val_loss=0.4890, val_f1=0.409, threshold=0.2
# Activation: relu, Epoch 2: train_loss=0.4374, val_loss=0.4602, val_f1=0.456, threshold=0.2
# Activation: relu, Epoch 3: train_loss=0.4166, val_loss=0.4408, val_f1=0.490, threshold=0.2
# Activation: relu, Epoch 4: train_loss=0.4072, val_loss=0.4283, val_f1=0.518, threshold=0.2
# Activation: relu, Epoch 5: train_loss=0.3954, val_loss=0.4182, val_f1=0.528, threshold=0.2
# Activation: relu, Epoch 6: train_loss=0.3816, val_loss=0.4119, val_f1=0.531, threshold=0.2
# Activation: relu, Epoch 7: train_loss=0.3727, val_loss=0.4087, val_f1=0.533, threshold=0.2
# Activation: relu, Epoch 8: train_loss=0.3803, val_loss=0.4049, val_f1=0.536, threshold=0.2
# Activation: relu, Epoch 9: train_loss=0.3861, val_loss=0.4039, val_f1=0.524, threshold=0.2
# Activation: relu, Epoch 10: train_loss=0.3664, val_loss=0.4029, val_f1=0.519, threshold=0.2
# Activation: relu, Epoch 11: train_loss=0.3799, val_loss=0.4016, val_f1=0.532, threshold=0.2
# Activation: relu, Epoch 12: train_loss=0.3587, val_loss=0.4014, val_f1=0.531, threshold=0.2
# Activation: relu, Epoch 13: train_loss=0.3616, val_loss=0.4015, val_f1=0.533, threshold=0.2
# Activation: relu, Epoch 14: train_loss=0.3558, val_loss=0.4009, val_f1=0.532, threshold=0.2
# Activation: relu, Epoch 15: train_loss=0.3711, val_loss=0.4010, val_f1=0.529, threshold=0.2
# Activation: relu, Epoch 16: train_loss=0.3669, val_loss=0.3997, val_f1=0.533, threshold=0.2
# Activation: relu, Epoch 17: train_loss=0.3689, val_loss=0.3987, val_f1=0.539, threshold=0.2
# Activation: relu, Epoch 18: train_loss=0.3552, val_loss=0.4008, val_f1=0.528, threshold=0.2
# Activation: relu, Epoch 19: train_loss=0.3340, val_loss=0.4016, val_f1=0.529, threshold=0.2
# Activation: relu, Epoch 20: train_loss=0.3641, val_loss=0.3981, val_f1=0.536, threshold=0.2
# Activation: relu, Epoch 21: train_loss=0.3562, val_loss=0.3980, val_f1=0.545, threshold=0.2
# Activation: relu, Epoch 22: train_loss=0.3562, val_loss=0.3978, val_f1=0.543, threshold=0.2
# Activation: relu, Epoch 23: train_loss=0.3509, val_loss=0.3978, val_f1=0.538, threshold=0.2
# Activation: relu, Epoch 24: train_loss=0.3449, val_loss=0.3978, val_f1=0.545, threshold=0.2
# Activation: relu, Epoch 25: train_loss=0.3524, val_loss=0.3973, val_f1=0.544, threshold=0.2
# Activation: relu, Epoch 26: train_loss=0.3456, val_loss=0.3962, val_f1=0.540, threshold=0.2
# Activation: relu, Epoch 27: train_loss=0.3581, val_loss=0.3952, val_f1=0.540, threshold=0.2
# Activation: relu, Epoch 28: train_loss=0.3502, val_loss=0.3946, val_f1=0.537, threshold=0.2
# Activation: relu, Epoch 29: train_loss=0.3579, val_loss=0.3950, val_f1=0.540, threshold=0.2
# Activation: relu, Epoch 30: train_loss=0.3482, val_loss=0.3968, val_f1=0.540, threshold=0.2
# Activation: relu, Epoch 31: train_loss=0.3445, val_loss=0.3947, val_f1=0.542, threshold=0.2
# Activation: relu, Epoch 32: train_loss=0.3406, val_loss=0.3950, val_f1=0.543, threshold=0.2
# Activation: relu, Epoch 33: train_loss=0.3477, val_loss=0.3963, val_f1=0.534, threshold=0.2
# Activation: relu, Epoch 34: train_loss=0.3391, val_loss=0.3965, val_f1=0.529, threshold=0.2
# Activation: relu, Epoch 35: train_loss=0.3469, val_loss=0.3959, val_f1=0.536, threshold=0.2
# Activation: relu, Epoch 36: train_loss=0.3459, val_loss=0.3951, val_f1=0.541, threshold=0.2
# Activation: relu, Epoch 37: train_loss=0.3541, val_loss=0.3950, val_f1=0.538, threshold=0.2
# Activation: relu, Epoch 38: train_loss=0.3332, val_loss=0.3951, val_f1=0.542, threshold=0.2
# Activation: relu, Epoch 39: train_loss=0.3356, val_loss=0.3948, val_f1=0.539, threshold=0.2
# Activation: relu, Epoch 40: train_loss=0.3319, val_loss=0.3955, val_f1=0.544, threshold=0.2
# Activation: relu, Epoch 41: train_loss=0.3318, val_loss=0.3952, val_f1=0.536, threshold=0.2
# Activation: relu, Epoch 42: train_loss=0.3182, val_loss=0.3978, val_f1=0.531, threshold=0.2
# Activation: relu, Epoch 43: train_loss=0.3405, val_loss=0.3989, val_f1=0.527, threshold=0.2
# Activation: relu, Epoch 44: train_loss=0.3278, val_loss=0.3967, val_f1=0.541, threshold=0.2
# Activation: relu, Epoch 45: train_loss=0.3384, val_loss=0.3947, val_f1=0.540, threshold=0.2
# Activation: relu, Epoch 46: train_loss=0.3258, val_loss=0.3957, val_f1=0.541, threshold=0.2
# Activation: relu, Epoch 47: train_loss=0.3244, val_loss=0.3988, val_f1=0.532, threshold=0.2
# Activation: relu, Epoch 48: train_loss=0.3300, val_loss=0.3941, val_f1=0.543, threshold=0.2
# Activation: relu, Epoch 49: train_loss=0.3273, val_loss=0.3945, val_f1=0.534, threshold=0.3
# Activation: relu, Epoch 50: train_loss=0.3337, val_loss=0.3956, val_f1=0.544, threshold=0.2
# Activation: relu, Epoch 51: train_loss=0.3383, val_loss=0.3954, val_f1=0.535, threshold=0.3
# Activation: relu, Epoch 52: train_loss=0.3295, val_loss=0.3949, val_f1=0.538, threshold=0.2
# Activation: relu, Epoch 53: train_loss=0.3212, val_loss=0.3942, val_f1=0.539, threshold=0.2
# Activation: relu, Epoch 54: train_loss=0.3377, val_loss=0.3940, val_f1=0.536, threshold=0.2
# Activation: relu, Epoch 55: train_loss=0.3321, val_loss=0.3933, val_f1=0.548, threshold=0.3
# Activation: relu, Epoch 56: train_loss=0.3311, val_loss=0.3950, val_f1=0.536, threshold=0.2
# Activation: relu, Epoch 57: train_loss=0.3264, val_loss=0.3944, val_f1=0.535, threshold=0.3
# Activation: relu, Epoch 58: train_loss=0.3241, val_loss=0.3985, val_f1=0.536, threshold=0.2
# Activation: relu, Epoch 59: train_loss=0.3232, val_loss=0.3951, val_f1=0.538, threshold=0.2
# Activation: relu, Epoch 60: train_loss=0.3246, val_loss=0.3940, val_f1=0.542, threshold=0.3
# Activation: relu, Epoch 61: train_loss=0.3177, val_loss=0.3947, val_f1=0.542, threshold=0.3
# Activation: relu, Epoch 62: train_loss=0.3234, val_loss=0.3958, val_f1=0.539, threshold=0.2
# Activation: relu, Epoch 63: train_loss=0.3219, val_loss=0.3938, val_f1=0.546, threshold=0.3
# Activation: relu, Epoch 64: train_loss=0.3237, val_loss=0.3935, val_f1=0.539, threshold=0.2
# Activation: relu, Epoch 65: train_loss=0.3365, val_loss=0.3942, val_f1=0.547, threshold=0.2
# Activation: relu, Epoch 66: train_loss=0.3207, val_loss=0.3940, val_f1=0.540, threshold=0.2
# Activation: relu, Epoch 67: train_loss=0.3211, val_loss=0.3930, val_f1=0.548, threshold=0.3
# Activation: relu, Epoch 68: train_loss=0.3220, val_loss=0.3956, val_f1=0.534, threshold=0.3
# Activation: relu, Epoch 69: train_loss=0.3159, val_loss=0.3937, val_f1=0.543, threshold=0.3
# Activation: relu, Epoch 70: train_loss=0.3262, val_loss=0.3923, val_f1=0.549, threshold=0.3
# Activation: relu, Epoch 71: train_loss=0.3322, val_loss=0.3926, val_f1=0.548, threshold=0.3
# Activation: relu, Epoch 72: train_loss=0.3200, val_loss=0.3932, val_f1=0.541, threshold=0.3
# Activation: relu, Epoch 73: train_loss=0.3323, val_loss=0.3920, val_f1=0.550, threshold=0.3
# Activation: relu, Epoch 74: train_loss=0.3229, val_loss=0.3935, val_f1=0.547, threshold=0.3
# Activation: sigmoid, Epoch 0: train_loss=0.5355, val_loss=0.5205, val_f1=0.339, threshold=0.1
# Activation: sigmoid, Epoch 1: train_loss=0.4904, val_loss=0.5025, val_f1=0.367, threshold=0.2
# Activation: sigmoid, Epoch 2: train_loss=0.4734, val_loss=0.4978, val_f1=0.502, threshold=0.2
# Activation: sigmoid, Epoch 3: train_loss=0.4692, val_loss=0.4925, val_f1=0.496, threshold=0.2
# Activation: sigmoid, Epoch 4: train_loss=0.4648, val_loss=0.4862, val_f1=0.506, threshold=0.2
# Activation: sigmoid, Epoch 5: train_loss=0.4704, val_loss=0.4792, val_f1=0.512, threshold=0.2
# Activation: sigmoid, Epoch 6: train_loss=0.4525, val_loss=0.4709, val_f1=0.492, threshold=0.2
# Activation: sigmoid, Epoch 7: train_loss=0.4551, val_loss=0.4627, val_f1=0.494, threshold=0.2
# Activation: sigmoid, Epoch 8: train_loss=0.4456, val_loss=0.4545, val_f1=0.500, threshold=0.2
# Activation: sigmoid, Epoch 9: train_loss=0.4331, val_loss=0.4470, val_f1=0.499, threshold=0.2
# Activation: sigmoid, Epoch 10: train_loss=0.4036, val_loss=0.4410, val_f1=0.515, threshold=0.2
# Activation: sigmoid, Epoch 11: train_loss=0.4236, val_loss=0.4344, val_f1=0.503, threshold=0.2
# Activation: sigmoid, Epoch 12: train_loss=0.4011, val_loss=0.4304, val_f1=0.512, threshold=0.2
# Activation: sigmoid, Epoch 13: train_loss=0.4009, val_loss=0.4268, val_f1=0.512, threshold=0.2
# Activation: sigmoid, Epoch 14: train_loss=0.4048, val_loss=0.4240, val_f1=0.526, threshold=0.2
# Activation: sigmoid, Epoch 15: train_loss=0.4015, val_loss=0.4212, val_f1=0.521, threshold=0.2
# Activation: sigmoid, Epoch 16: train_loss=0.4118, val_loss=0.4195, val_f1=0.521, threshold=0.2
# Activation: sigmoid, Epoch 17: train_loss=0.4128, val_loss=0.4181, val_f1=0.526, threshold=0.2
# Activation: sigmoid, Epoch 18: train_loss=0.4017, val_loss=0.4170, val_f1=0.526, threshold=0.2
# Activation: sigmoid, Epoch 19: train_loss=0.4038, val_loss=0.4155, val_f1=0.527, threshold=0.2
# Activation: sigmoid, Epoch 20: train_loss=0.3924, val_loss=0.4146, val_f1=0.529, threshold=0.2
# Activation: sigmoid, Epoch 21: train_loss=0.3822, val_loss=0.4143, val_f1=0.532, threshold=0.2
# Activation: sigmoid, Epoch 22: train_loss=0.3845, val_loss=0.4139, val_f1=0.531, threshold=0.2
# Activation: sigmoid, Epoch 23: train_loss=0.3851, val_loss=0.4128, val_f1=0.535, threshold=0.2
# Activation: sigmoid, Epoch 24: train_loss=0.4036, val_loss=0.4120, val_f1=0.534, threshold=0.2
# Activation: sigmoid, Epoch 25: train_loss=0.3932, val_loss=0.4121, val_f1=0.530, threshold=0.2
# Activation: sigmoid, Epoch 26: train_loss=0.3940, val_loss=0.4113, val_f1=0.532, threshold=0.2
# Activation: sigmoid, Epoch 27: train_loss=0.3901, val_loss=0.4106, val_f1=0.538, threshold=0.2
# Activation: sigmoid, Epoch 28: train_loss=0.3914, val_loss=0.4103, val_f1=0.537, threshold=0.2
# Activation: sigmoid, Epoch 29: train_loss=0.4015, val_loss=0.4102, val_f1=0.534, threshold=0.2
# Activation: sigmoid, Epoch 30: train_loss=0.3910, val_loss=0.4103, val_f1=0.538, threshold=0.2
# Activation: sigmoid, Epoch 31: train_loss=0.3829, val_loss=0.4101, val_f1=0.538, threshold=0.2
# Activation: sigmoid, Epoch 32: train_loss=0.3882, val_loss=0.4094, val_f1=0.537, threshold=0.2
# Activation: sigmoid, Epoch 33: train_loss=0.3964, val_loss=0.4097, val_f1=0.542, threshold=0.2
# Activation: sigmoid, Epoch 34: train_loss=0.3931, val_loss=0.4090, val_f1=0.536, threshold=0.2
# Activation: sigmoid, Epoch 35: train_loss=0.3838, val_loss=0.4089, val_f1=0.538, threshold=0.2
# Activation: sigmoid, Epoch 36: train_loss=0.3924, val_loss=0.4087, val_f1=0.540, threshold=0.2
# Activation: sigmoid, Epoch 37: train_loss=0.3858, val_loss=0.4093, val_f1=0.541, threshold=0.2
# Activation: sigmoid, Epoch 38: train_loss=0.4008, val_loss=0.4083, val_f1=0.540, threshold=0.2
# Activation: sigmoid, Epoch 39: train_loss=0.3917, val_loss=0.4085, val_f1=0.541, threshold=0.2
# Activation: sigmoid, Epoch 40: train_loss=0.3779, val_loss=0.4086, val_f1=0.541, threshold=0.2
# Activation: sigmoid, Epoch 41: train_loss=0.3735, val_loss=0.4085, val_f1=0.541, threshold=0.2
# Activation: sigmoid, Epoch 42: train_loss=0.3790, val_loss=0.4086, val_f1=0.543, threshold=0.2
# Activation: sigmoid, Epoch 43: train_loss=0.3960, val_loss=0.4078, val_f1=0.546, threshold=0.2
# Activation: sigmoid, Epoch 44: train_loss=0.3830, val_loss=0.4079, val_f1=0.548, threshold=0.2
# Activation: sigmoid, Epoch 45: train_loss=0.3955, val_loss=0.4076, val_f1=0.550, threshold=0.2
# Activation: sigmoid, Epoch 46: train_loss=0.3849, val_loss=0.4073, val_f1=0.549, threshold=0.2
# Activation: sigmoid, Epoch 47: train_loss=0.3797, val_loss=0.4078, val_f1=0.545, threshold=0.2
# Activation: sigmoid, Epoch 48: train_loss=0.3843, val_loss=0.4078, val_f1=0.543, threshold=0.2
# Activation: sigmoid, Epoch 49: train_loss=0.3903, val_loss=0.4070, val_f1=0.549, threshold=0.2
# Activation: sigmoid, Epoch 50: train_loss=0.3721, val_loss=0.4069, val_f1=0.549, threshold=0.2
# Activation: sigmoid, Epoch 51: train_loss=0.3873, val_loss=0.4075, val_f1=0.546, threshold=0.2
# Activation: sigmoid, Epoch 52: train_loss=0.3798, val_loss=0.4071, val_f1=0.547, threshold=0.2
# Activation: sigmoid, Epoch 53: train_loss=0.3942, val_loss=0.4066, val_f1=0.547, threshold=0.2
# Activation: sigmoid, Epoch 54: train_loss=0.3937, val_loss=0.4062, val_f1=0.548, threshold=0.2
# Activation: sigmoid, Epoch 55: train_loss=0.3930, val_loss=0.4066, val_f1=0.547, threshold=0.2
# Activation: sigmoid, Epoch 56: train_loss=0.3799, val_loss=0.4066, val_f1=0.550, threshold=0.2
# Activation: sigmoid, Epoch 57: train_loss=0.3869, val_loss=0.4066, val_f1=0.547, threshold=0.2
# Activation: sigmoid, Epoch 58: train_loss=0.3959, val_loss=0.4059, val_f1=0.547, threshold=0.2
# Activation: sigmoid, Epoch 59: train_loss=0.3902, val_loss=0.4056, val_f1=0.545, threshold=0.2
# Activation: sigmoid, Epoch 60: train_loss=0.3799, val_loss=0.4056, val_f1=0.545, threshold=0.2
# Activation: sigmoid, Epoch 61: train_loss=0.3732, val_loss=0.4057, val_f1=0.544, threshold=0.2
# Activation: sigmoid, Epoch 62: train_loss=0.3745, val_loss=0.4061, val_f1=0.549, threshold=0.2
# Activation: sigmoid, Epoch 63: train_loss=0.3892, val_loss=0.4052, val_f1=0.539, threshold=0.2
# Activation: sigmoid, Epoch 64: train_loss=0.3888, val_loss=0.4049, val_f1=0.538, threshold=0.2
# Activation: sigmoid, Epoch 65: train_loss=0.3979, val_loss=0.4050, val_f1=0.547, threshold=0.2
# Activation: sigmoid, Epoch 66: train_loss=0.3799, val_loss=0.4053, val_f1=0.545, threshold=0.2
# Activation: sigmoid, Epoch 67: train_loss=0.3793, val_loss=0.4048, val_f1=0.544, threshold=0.2
# Activation: sigmoid, Epoch 68: train_loss=0.3942, val_loss=0.4048, val_f1=0.549, threshold=0.2
# Activation: sigmoid, Epoch 69: train_loss=0.3751, val_loss=0.4048, val_f1=0.550, threshold=0.2
# Activation: sigmoid, Epoch 70: train_loss=0.3839, val_loss=0.4046, val_f1=0.548, threshold=0.2
# Activation: sigmoid, Epoch 71: train_loss=0.3777, val_loss=0.4045, val_f1=0.547, threshold=0.2
# Activation: sigmoid, Epoch 72: train_loss=0.4085, val_loss=0.4041, val_f1=0.548, threshold=0.2
# Activation: sigmoid, Epoch 73: train_loss=0.3855, val_loss=0.4039, val_f1=0.542, threshold=0.3
# Activation: sigmoid, Epoch 74: train_loss=0.3771, val_loss=0.4043, val_f1=0.549, threshold=0.2
#    epoch  step activation  train_loss  val_loss  f1_score lipschitz_upper  \
# 0      0   0.0       relu         NaN       NaN       NaN  tensor(0.0151)
# 1      0   1.0       relu         NaN       NaN       NaN  tensor(0.0151)
# 2      0   2.0       relu         NaN       NaN       NaN  tensor(0.0151)
# 3      0   3.0       relu         NaN       NaN       NaN  tensor(0.0151)
# 4      0   4.0       relu         NaN       NaN       NaN  tensor(0.0152)
#
#   lipschitz_lower  max_hessian_eigval
# 0     0.030816607            0.759713
# 1     0.028119916            0.493135
# 2      0.03446823            0.446492
# 3     0.033980414            0.524000
# 4      0.03324649            0.509852
